# %%
from fastapi import FastAPI

app = FastAPI(title="WLA RAG", version="0.1.0")

@app.get("/health")
def health():
    return {"ok": True, "service": "fastapi"}

# %%
import nest_asyncio, uvicorn, os
nest_asyncio.apply()

port = int(os.getenv("RAG_PORT", "8000"))
config = uvicorn.Config(app, host="0.0.0.0", port=port, reload=False, log_level="info")
server = uvicorn.Server(config)
await server.serve()
# Out:
# INFO:     Started server process [13121]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# INFO:     127.0.0.1:47946 - "GET /health HTTP/1.1" 200 OK
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [13121]
