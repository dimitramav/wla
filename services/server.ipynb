# %%
import nest_asyncio, uvicorn, os
from api.main import create_app  # Ensure api.py is in the same directory or PYTHONPATH

app = create_app()
nest_asyncio.apply()

port = int(os.getenv("RAG_PORT", "8000"))
config = uvicorn.Config(app, host="0.0.0.0", port=port, reload=False, log_level="info")
server = uvicorn.Server(config)
print("Server ready on port", port)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 import nest_asyncio, uvicorn, os
# ----> 2 from api import create_app  # Ensure api.py is in the same directory or PYTHONPATH
#       4 app = create_app()
#       5 nest_asyncio.apply()
#
# File ~/wla/services/api.py:2
#       1 from fastapi import FastAPI, HTTPException, Path, Query
# ----> 2 from .settings import read_docsets_meta
#       3 from .vecstore import collection_for
#       4 from .ingest import ingest_topic
#
# ImportError: attempted relative import with no known parent package

# %%
await server.serve()
# Out:
# Summary generated: {'topic': 'school_anxiety', 'hash': 'fc225f973d6ee8b227ab5f439215ca9257bd3418689f84686961aaf6a44958b6', 'bullets': ['I. Introduction', '* School anxiety refers to feelings of fear, apprehension, and discomfort in school settings.', '* This can be caused by various factors such as academic pressure, social isolation, or difficult interactions with peers or authority figures.', 'II. Prevalence of School Anxiety', '* It is estimated that 5-10% of children experience significant school anxiety symptoms.', '* Rates may increase during times of transition, such as moving between schools or grade levels.', 'III. Symptoms of School Anxiety', '* Common symptoms include excessive worry, negative thoughts, avoidance behaviors, and physical symptoms such as stomachaches and headaches.', '* Children with school anxiety may also struggle academically, socially, and in other areas of their lives.', 'IV. Assessing School Anxiety'], 'promptHash': '5819d766b9', 'seed': 7}
# INFO:     127.0.0.1:39938 - "GET /rag/summary?topic=school_anxiety HTTP/1.1" 200 OK
# Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given
# Summary generated: {'topic': 'school_anxiety', 'hash': 'fc225f973d6ee8b227ab5f439215ca9257bd3418689f84686961aaf6a44958b6', 'bullets': ['* Introduction: School anxiety is a common experience for students, characterized by worry or fear about school events or performance.', '* Types of school anxiety: Some common types include test anxiety, public speaking anxiety, study skills anxiety, peer pressure anxiety, and social anxiety.', '* Symptoms: Students with school anxiety may experience physical symptoms such as stomachaches, muscle tension, and sweating, as well as psychological symptoms such as feeling overwhelmed, anxious, or depressed.', '* Causes: There are various causes of school anxiety, including academic expectations, social pressures, and a history of anxiety or mental health conditions.', '* Strategies to manage school anxiety:', '+ Encourage your students to practice relaxation techniques, such as deep breathing, meditation, or yoga.', '+ Help them break down large tasks into smaller, more manageable parts and set realistic goals.', '+ Provide resources on study skills, time management, and test-taking strategies that can help improve performance and reduce stress.', '+ Encourage open communication with teachers, counselors, or coaches who can provide support and guidance.', '+ Help students develop a support system with friends, family, or peer groups who understand the challenges of school.'], 'promptHash': '5819d766b9', 'seed': 7}
# INFO:     127.0.0.1:54646 - "GET /rag/summary?topic=school_anxiety HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53012 - "GET /health HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55930 - "GET /health HTTP/1.1" 200 OK
